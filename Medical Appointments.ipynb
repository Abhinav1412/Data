# %%
import pandas as pd

Medical_Appointments = pd.read_csv("Medical_Appointments.csv")

pd.options.display.float_format = '{:.0f}'.format
Medical_Appointments.head()
# Out:
#         PatientId  AppointmentID Gender          ScheduledDay  \
# 0  29872499824296        5642903      F  2016-04-29T18:38:08Z
# 1 558997776694438        5642503      M  2016-04-29T16:08:27Z
# 2   4262962299951        5642549      F  2016-04-29T16:19:04Z
# 3    867951213174        5642828      F  2016-04-29T17:29:31Z
# 4   8841186448183        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
Medical_Appointments.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
Medical_Appointments.duplicated().sum()
# Out:
# 0

# %%
Medical_Appointments[Medical_Appointments.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received, No-show]
# Index: []

# %%
Medical_Appointments.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %%
Medical_Appointments['ScheduledDay'] = pd.to_datetime(Medical_Appointments['ScheduledDay'])

Medical_Appointments['AppointmentDay'] = pd.to_datetime(Medical_Appointments['AppointmentDay'])

# %%
Medical_Appointments.dtypes
# Out:
# PatientId                     float64
# AppointmentID                   int64
# Gender                         object
# ScheduledDay      datetime64[ns, UTC]
# AppointmentDay    datetime64[ns, UTC]
# Age                             int64
# Neighbourhood                  object
# Scholarship                     int64
# Hipertension                    int64
# Diabetes                        int64
# Alcoholism                      int64
# Handcap                         int64
# SMS_received                    int64
# No-show                        object
# dtype: object

# %%
Medical_Appointments.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
Medical_Appointments.head()
# Out:
#         PatientId  AppointmentID Gender              ScheduledDay  \
# 0  29872499824296        5642903      F 2016-04-29 18:38:08+00:00
# 1 558997776694438        5642503      M 2016-04-29 16:08:27+00:00
# 2   4262962299951        5642549      F 2016-04-29 16:19:04+00:00
# 3    867951213174        5642828      F 2016-04-29 17:29:31+00:00
# 4   8841186448183        5642494      F 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0             1         0           0        0             0      No
# ...

# %%
Medical_Appointments.rename(columns = {'PatientId': 'PatientID', 'Hipertension': 'Hypertension', 'Handcap': 'Handicap' }, inplace=True)

Medical_Appointments.head(20)
# Out:
#          PatientID  AppointmentID Gender              ScheduledDay  \
# 0   29872499824296        5642903      F 2016-04-29 18:38:08+00:00
# 1  558997776694438        5642503      M 2016-04-29 16:08:27+00:00
# 2    4262962299951        5642549      F 2016-04-29 16:19:04+00:00
# 3     867951213174        5642828      F 2016-04-29 17:29:31+00:00
# 4    8841186448183        5642494      F 2016-04-29 16:07:23+00:00
# 5   95985133231274        5626772      F 2016-04-27 08:36:51+00:00
# 6  733688164476661        5630279      F 2016-04-27 15:05:12+00:00
# 7    3449833394123        5630575      F 2016-04-27 15:39:58+00:00
# 8   56394729949972        5638447      F 2016-04-29 08:02:16+00:00
# 9   78124564369297        5629123      F 2016-04-27 12:48:25+00:00
# 10 734536231958495        5630213      F 2016-04-27 14:58:11+00:00
# 11   7542951368435        5620163      M 2016-04-26 08:44:12+00:00
# 12 566654781423437        5634718      F 2016-04-28 11:33:51+00:00
# ...

# %%
Medical_Appointments.isnull().sum()
# Out:
# PatientID         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hypertension      0
# Diabetes          0
# Alcoholism        0
# Handicap          0
# SMS_received      0
# No-show           0
# dtype: int64
